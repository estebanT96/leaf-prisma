# %%
import ee
import geemap

# ee.Authenticate()
ee.Initialize(project='leaf-prisma')

# Your Map
Map = geemap.Map(center=[29.42019, -110.91778], zoom=16)
Map.add_basemap('HYBRID')

# Just type 'Map' on the last line to show it
Map
# Out:
# Map(center=[29.42019, -110.91778], controls=(WidgetControl(options=['position', 'transparent_bg'], position='t…
